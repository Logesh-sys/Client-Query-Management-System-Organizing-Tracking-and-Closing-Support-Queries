# %% [markdown]
# <a href="https://colab.research.google.com/github/Logesh-sys/Client-Query-Management-System-Organizing-Tracking-and-Closing-Support-Queries/blob/main/Client_Support_Query_Portal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
